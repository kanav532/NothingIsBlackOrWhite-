# %%
   '''
The architecture for the GAN consists of 2 sections: Generator and Discriminator. 

The Generator architecture follows the UNet architecture found in the image below (Also shown in the project proposal).

The Discriminator Architercture uses similar to bselines contractive path. 

We use a series of convolutional blocks that are consistent of the following: 

    -- nn.conv2d
    -- nn.BatchNorm2d
    -- nn.ReLU or nn.LeakyReLU

We create a class that returns a block of the above components using nn.Sequential.
'''

# %%
import torch 
import torch.nn as nn
import torch.nn.functional as F

# %%
#Convolutional block using ReLU
class ConvBlock_Relu(nn.Module):
    def __init__(self, in_size, out_size, kernel_size, stride=2, padding=1, bias=True):
        super(ConvBlock_Relu, self).__init__()

        self.model = nn.Sequential(
        nn.Conv2d(in_size, out_size, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias),
        nn.BatchNorm2d(out_size),
        nn.ReLU() 
        )

    def forward(self, x):
        x = self.model(x)
        return x

#Convolutional block using Leaky ReLU
class ConvBlock_Leaky_Relu(nn.Module):
    def __init__(self, in_size, out_size, kernel_size, stride=2, padding=1, bias=True):
        super(ConvBlock_Leaky_Relu, self).__init__()

        self.model = nn.Sequential(
        nn.Conv2d(in_size, out_size, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias),
        nn.BatchNorm2d(out_size),
        nn.LeakyReLU(0.2) 
        )

    def forward(self, x):
        x = self.model(x)
        return x

# %%
#DeConvolutional block using ReLU
class DeconvBlock_Relu(nn.Module):
    def __init__(self, in_size, out_size, kernel_size, stride=2, padding=1, output_padding=0, bias=True):
        super(DeconvBlock_Relu, self).__init__()

        self.model = nn.Sequential(
          nn.ConvTranspose2d(in_size, out_size, kernel_size=kernel_size, stride=stride, padding=padding,output_padding=output_padding, bias=bias),
          nn.BatchNorm2d(out_size),
          nn.ReLU() 
        )

    def forward(self, x):
        x = self.model(x)
        return x

#DeConvolutional block using Leaky ReLU
class DeconvBlock_Leaky_Relu(nn.Module):
    def __init__(self, in_size, out_size, kernel_size, stride=2, padding=1,output_padding=0, bias=True):
        super(DeconvBlock_Relu, self).__init__()

        self.model = nn.Sequential(
          nn.ConvTranspose2d(in_size, out_size, kernel_size=kernel_size, stride=stride, padding=padding,output_padding=output_padding, bias=bias),
          nn.BatchNorm2d(out_size),
          nn.LeakyReLU(0.2) 
        )

    def forward(self, x):
        x = self.model(x)
        return x

# %%
#Generator Model Class
class GeneratorModel(nn.Module):
    def __init__(self):
        super(GeneratorModel, self).__init__()

        #Convolutional layers
        self.conv1 = ConvBlock_Relu(1, 64, kernel_size=3, stride=2, padding=1, bias=False)
        self.conv2 = ConvBlock_Relu(64, 128, kernel_size=3, stride=2, padding=1, bias=False)
        self.conv3 = ConvBlock_Relu(128, 256, kernel_size=3, stride=2, padding=1, bias=False)
        self.conv4 = ConvBlock_Relu(256, 512, kernel_size=3, stride=2, padding=1, bias=False)
        self.conv5 = ConvBlock_Relu(512, 512, kernel_size=3, stride=2, padding=1, bias=False)

        #Deconvolutional layers
        self.deconv1 = DeconvBlock_Relu(512, 512, kernel_size=3, stride=2, padding=1, output_padding=1, bias=False)
        self.deconv2 = DeconvBlock_Relu(512, 256, kernel_size=3, stride=2, padding=1, output_padding=1,bias=False)
        self.deconv3 = DeconvBlock_Relu(256, 128, kernel_size=3, stride=2, padding=1, output_padding=1,bias=False)
        self.deconv4 = DeconvBlock_Relu(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1,bias=False)
        self.deconv5 = DeconvBlock_Relu(64, 3, kernel_size=3, stride=2, padding=1, output_padding=1,bias=False)

        self.conv7 = ConvBlock_Relu(128, 2, kernel_size=1, stride=1, padding=0)


    def forward(self, x):
        #Encoding layers
        x1 = self.conv1(x)
        x2 = self.conv2(x1)
        x3 = self.conv3(x2)
        x4 = self.conv4(x3)
        x5 = self.conv5(x4)

        #Decoding Layers
        x6 = self.deconv1(x5) + x4
        x7 = self.deconv2(x6) + x3
        x8 = self.deconv3(x7) +x2
        x9 = self.deconv4(x8) + x1
        x10 = self.deconv5(x9)

        x11 = torch.tanh(x10)
        return x11

# %%
#Dscriminator Model Class
class DiscriminatorModel(nn.Module):
    def __init__(self):
        super(DiscriminatorModel, self).__init__()
        
        self.conv1 = ConvBlock_Relu(3, 64, kernel_size=3, stride=2, padding=1, bias = False)
        self.conv2 = ConvBlock_Relu(64, 128, kernel_size=3, stride=2, padding=1, bias=False)
        self.conv3 = ConvBlock_Relu(128, 256, kernel_size=3, stride=2, padding=1, bias=False)
        self.conv4 = ConvBlock_Relu(256, 512, kernel_size=3, stride=2, padding=1, bias=False)
        self.conv5 = ConvBlock_Relu(512, 512, kernel_size=3, stride=2, padding=0, bias=False)
        self.conv6 = ConvBlock_Relu(512, 1, kernel_size=1, stride=1, padding=0, bias=False)
        #self.conv7 = ConvBlock_Relu(512, 1, kernel_size=1, stride=1, padding=0, bias=False)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        self.fc = nn.Linear(36, 1)

    def forward(self, x):
        #Convolutional Layers with pooling in between
        x1 = self.conv1(x)
        #x2 = self.pool(x1)
        x3 = self.conv2(x1)
        #x4 = self.pool(x3)
        x5 = self.conv3(x3)
        #x6 = self.pool(x5)
        x7 = self.conv4(x5)
        #x8 = self.pool(x7)
        x9 = self.conv5(x7)
        #x10 = self.pool(x9)

        #Fully connected layers
        x11 = self.conv6(x9)
        x12 = x11.view(-1, 36)
        x13 = self.fc(x12)
        return torch.sigmoid(x13)

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, models, transforms
from torch.utils.data.sampler import SubsetRandomSampler
import cv2

import random
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import torch.utils.data as Data
from torch.autograd import Variable
from skimage import color

# import tensorflow as tf
# import tensorflow_datasets as tfds

torch.manual_seed(1)
np.random.seed(1000)

# %%
#Adrians Data Loaders
from google.colab import drive
drive.mount('/content/drive')
master_path = '/content/drive/My Drive/Year 3 Groupwork/APS360 Project/Code and Core Project/Datasets/Flickr30k Dataset/flickr30k_images'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_dir = '/content/drive/My Drive/Year 3 Groupwork/APS360 Project/Code And Core Project/Datasets/Flickr30k Dataset/'
# resize all images to 224 x 224
data_transform = transforms.Compose([transforms.Resize((224,224)), 
                                      transforms.ToTensor()])

main_dataset = datasets.ImageFolder(data_dir, transform=data_transform)

# print out some data stats
print('Num of input images: ', len(main_dataset))
# Out:
# Num of input images:  11080

# %%
###############################################################################
# Data Loading

def get_relevant_indices(dataset):
    """ Return the indices for datapoints in the dataset that belongs to the
    desired target classes, a subset of all possible classes.

    Args:
        dataset: Dataset object
        classes: A list of strings denoting the name of each class
        target_classes: A list of strings denoting the name of desired classes
                        Should be a subset of the 'classes'
    Returns:
        indices: list of indices that have labels corresponding to one of the
                 target classes
    """
    indices = []
    for i in range(len(dataset)):
        # # Check if the label is in the target classes
        # label_index = dataset[i][1] # ex: 3
        # label_class = classes[label_index] # ex: 'cat'
        # if label_class in target_classes:
          indices.append(i)
    return indices

def get_data_loader(dataset, batch_size, splt_1, splt_2):
    """ Loads images of hands, splits the data into training, validation
    and testing datasets. Returns data loaders for the three preprocessed datasets.

    Args:
        target_classes: A list of strings denoting the name of the desired
                        classes. Should be a subset of the argument 'classes'
        batch_size: A int representing the number of samples per batch
    
    Returns:
        train_loader: iterable training dataset organized according to batch size
        val_loader: iterable validation dataset organized according to batch size
        test_loader: iterable testing dataset organized according to batch size
        classes: A list of strings denoting the name of each class
    """

    ########################################################################

    # Get the list of indices to sample from
    relevant_indices = get_relevant_indices(dataset)
    
    # Split into train and validation
    np.random.seed(1000) # Fixed numpy random seed for reproducible shuffling
    np.random.shuffle(relevant_indices)
    split1 = int(len(relevant_indices) * splt_1) #split1 at 75%
    split2 = int(len(relevant_indices) * splt_2) #split1 at 90%
    
    # split into training and validation indices
    relevant_train_indices, relevant_val_indices, relevant_test_indices = relevant_indices[:split1], relevant_indices[split1:split2], relevant_indices[split2:]   
    train_sampler = SubsetRandomSampler(relevant_train_indices)
    train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                               num_workers=1, sampler=train_sampler)
    val_sampler = SubsetRandomSampler(relevant_val_indices)
    val_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                              num_workers=1, sampler=val_sampler)
    test_sampler = SubsetRandomSampler(relevant_test_indices)
    test_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                             num_workers=1, sampler=test_sampler)
    
    print('Number of train images: ', len(relevant_train_indices))
    print('Number of validation images: ', len(relevant_val_indices))
    print('Number of testing images: ', len(relevant_test_indices))
    return train_loader, val_loader, test_loader

###############################################################################

# %%
###############################################################################
BATCH_SIZE = 1

train_loader, val_loader, test_loader = get_data_loader(
    dataset=main_dataset,
    batch_size=BATCH_SIZE, 
    splt_1=0.1, 
    splt_2=0.95)
# Out:
# Number of train images:  1108
# Number of validation images:  9418
# Number of testing images:  554

# %%
def train_GAN(generator_model, discriminator_model, train_loader, val_loader, lmda, batch_size=256, num_epochs=10, lr=0.001):
    iters = []
    #Setup For Generator
    criterion_gen = nn.BCELoss()
    criterion_gen_2 = nn.L1Loss()
    optimizer_gen = optim.Adam(generator_model.parameters(), lr=lr)
    gen_losses, gen_train_acc, gen_val_acc = [], [], []

    #Discriminator Setup
    criterion_disc = nn.BCELoss()
    optimizer_disc = optim.Adam(discriminator_model.parameters(), lr=lr)
    disc_losses, disc_train_acc, disc_val_acc = [], [], []

    generator_model.train()
    discriminator_model.train()
    for epoch in range(num_epochs):
        print('epoch #: ' + str(epoch))
        real_found = 0
        real_count = 0
        fake_count = 0
        fake_found = 0
        count = 0
        for step, (img_lab, clas) in enumerate(train_loader):
            #if(count %100 == 0):
              #print(count)
            count+=1
            #####Discriminator Training ######
            optimizer_disc.zero_grad()
            img_gray = img_lab[:,0:1,:,:]
            #Train with real images
           # print("real training")

            out_real_disc = discriminator_model(img_lab)
            if(out_real_disc > 0.5):
              real_found +=1
            real_count+=1
            
            #print(out_real_disc.shape)
            label_real = torch.FloatTensor(img_lab.size(0)).fill_(1)
            label_real_v = Variable(label_real)
            #print(label_real_v)
            real_labels = torch.ones(img_lab.shape[0], 1)
            loss_real_disc = criterion_disc(out_real_disc , real_labels.float())

            #Train with fake images
            fake_data =  generator_model(img_gray)
            out_fake_disc = discriminator_model(fake_data.detach())
            if(out_fake_disc < 0.5):
              fake_found +=1
            fake_count +=1
            label_fake = torch.FloatTensor(fake_data.size(0)).fill_(0)
            label_fake_v = Variable(label_fake)
            fake_labels = torch.zeros(img_lab.shape[0], 1)
            loss_fake_disc = criterion_disc(out_fake_disc, fake_labels.float())

            loss_disc = (loss_fake_disc + loss_real_disc) /2
            loss_disc.backward()
            optimizer_disc.step()


            #####Generator Training ######
            optimizer_gen.zero_grad()
            disc_out = discriminator_model(fake_data)
            loss_GAN = criterion_gen(disc_out, real_labels)
            loss_l1 = criterion_gen_2(fake_data.view(fake_data.size(0),-1), img_lab.view(img_lab.size(0),-1))
            loss_gen = (1.0-lmda) * loss_GAN + lmda*loss_l1;
            

            loss_gen.backward()
            optimizer_gen.step()
        
        iters.append(epoch)
        gen_losses.append(float(loss_gen)/batch_size)
        disc_losses.append(float(loss_disc)/batch_size)
        print('gen loss: ' + str(float(loss_gen)) + ' | disc_loss: ' + str(float(loss_disc)))
        print("correctly identified real: " + str(real_found) + " / " + str(real_count))
        print("correctly identified fake: " + str(fake_found) + " / " + str(fake_count))
        print("total count", count)

    # plotting
    plt.title("Training Curve")
    plt.plot(iters, gen_losses, label="Gen Losses")
    plt.plot(iters, disc_losses, label="Disc Losses")
    plt.xlabel("Iterations")
    plt.ylabel("Loss")
    plt.show()

# %%
gen_model = GeneratorModel()
disc_model = DiscriminatorModel()

train_GAN(generator_model=gen_model, discriminator_model=disc_model, train_loader=train_loader, val_loader=val_loader,num_epochs=30, lmda=0.98)

# %%
fake_found = 0
tot_count = 0
for step, (img_lab, clas) in enumerate(test_loader):
      grey_img = img_lab[:,0:1,:,:]
      tot_count +=1
      output = gen_model(grey_img)
      out_fake_disc = disc_model(output.detach())
      if(out_fake_disc < 0.5):
          fake_found +=1

print("It detected the following number of generated images as fake" + str(fake_found) + "/" + str(tot_count))
# Out:
# It detected the following number of generated images as fake518/554

# %%
test_count = 0
import random
from skimage import color, io
predicted_rgb_batch = []
num = random.randint(0,1000)
for step, (img_lab, clas) in enumerate(test_loader):
    grey_img = img_lab[:,0:1,:,:]
    output = gen_model(grey_img)
    out_fake_disc = disc_model(output.detach())
    if(out_fake_disc < 0.5):
        predicted_rgb_img = color.lab2rgb(np.transpose(output[0].detach().numpy().astype('float64'), (1, 2, 0)))
        predicted_rgb_batch.append(torch.FloatTensor(output[0]))
        break

fig, ax = plt.subplots(figsize=(15, 15), nrows=1, ncols=2)
ax[0].imshow(np.transpose(torchvision.utils.make_grid(torch.stack(predicted_rgb_batch), nrow=5).detach().numpy(), (1, 2, 0)))
plt.show()

# %%
###############################################################################
BATCH_SIZE = 1

train_loader, val_loader, test_loader = get_data_loader(
    dataset=main_dataset,
    batch_size=BATCH_SIZE, 
    splt_1 =0.001, 
    splt_2 = 0.95)
# Out:
# Number of train images:  11
# Number of validation images:  10515
# Number of testing images:  554

# %%
gen_model_2 = GeneratorModel()
disc_model_2 = DiscriminatorModel()

train_GAN(generator_model=gen_model, discriminator_model=disc_model, train_loader=train_loader, val_loader=val_loader,num_epochs=150, lmda=0.995)
# Out:
# epoch #: 0
# gen loss: 0.09623008221387863 | disc_loss: 0.12132591754198074
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 1
# gen loss: 0.13625724613666534 | disc_loss: 1.2280571460723877
# correctly identified real: 10 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 2
# gen loss: 0.06796763837337494 | disc_loss: 0.42939573526382446
# correctly identified real: 10 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 3
# gen loss: 0.06315983831882477 | disc_loss: 0.045091867446899414
# correctly identified real: 9 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 4
# gen loss: 0.06090833619236946 | disc_loss: 0.7509978413581848
# correctly identified real: 10 / 11
# correctly identified fake: 7 / 11
# total count 11
# epoch #: 5
# gen loss: 0.09613431245088577 | disc_loss: 0.06346327066421509
# correctly identified real: 8 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 6
# gen loss: 0.05003361031413078 | disc_loss: 0.6016393899917603
# correctly identified real: 11 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 7
# gen loss: 0.061302971094846725 | disc_loss: 0.2778436839580536
# correctly identified real: 11 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 8
# gen loss: 0.06081094592809677 | disc_loss: 0.1862040013074875
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 9
# gen loss: 0.044349122792482376 | disc_loss: 0.39124348759651184
# correctly identified real: 11 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 10
# gen loss: 0.05496516451239586 | disc_loss: 0.44859930872917175
# correctly identified real: 9 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 11
# gen loss: 0.05229053646326065 | disc_loss: 0.18569828569889069
# correctly identified real: 8 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 12
# gen loss: 0.06703293323516846 | disc_loss: 0.22123835980892181
# correctly identified real: 11 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 13
# gen loss: 0.11556126177310944 | disc_loss: 0.11857692152261734
# correctly identified real: 9 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 14
# gen loss: 0.06528693437576294 | disc_loss: 0.0472639799118042
# correctly identified real: 9 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 15
# gen loss: 0.054294999688863754 | disc_loss: 0.6605172157287598
# correctly identified real: 9 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 16
# gen loss: 0.051788751035928726 | disc_loss: 0.25893497467041016
# correctly identified real: 11 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 17
# gen loss: 0.060325924307107925 | disc_loss: 0.10491055250167847
# correctly identified real: 9 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 18
# gen loss: 0.08716554939746857 | disc_loss: 0.12094888836145401
# correctly identified real: 10 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 19
# gen loss: 0.0528082512319088 | disc_loss: 0.6678163409233093
# correctly identified real: 9 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 20
# gen loss: 0.09109176695346832 | disc_loss: 0.076933853328228
# correctly identified real: 10 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 21
# gen loss: 0.05235251039266586 | disc_loss: 0.14340415596961975
# correctly identified real: 11 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 22
# gen loss: 0.09940646588802338 | disc_loss: 0.02426028810441494
# correctly identified real: 11 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 23
# gen loss: 0.09761366248130798 | disc_loss: 0.027208246290683746
# correctly identified real: 11 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 24
# gen loss: 0.08029539883136749 | disc_loss: 0.318328320980072
# correctly identified real: 11 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 25
# gen loss: 0.09357184171676636 | disc_loss: 0.02537241019308567
# correctly identified real: 11 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 26
# gen loss: 0.06056569516658783 | disc_loss: 0.07070784270763397
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 27
# gen loss: 0.06379255652427673 | disc_loss: 0.09379862993955612
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 28
# gen loss: 0.12104491144418716 | disc_loss: 0.022163651883602142
# correctly identified real: 11 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 29
# gen loss: 0.05586584657430649 | disc_loss: 0.7971509695053101
# correctly identified real: 9 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 30
# gen loss: 0.05256807431578636 | disc_loss: 1.1081076860427856
# correctly identified real: 11 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 31
# gen loss: 0.05979801341891289 | disc_loss: 0.09823177754878998
# correctly identified real: 7 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 32
# gen loss: 0.10791114717721939 | disc_loss: 1.0604430437088013
# correctly identified real: 8 / 11
# correctly identified fake: 8 / 11
# total count 11
# epoch #: 33
# gen loss: 0.06182330846786499 | disc_loss: 0.11063501238822937
# correctly identified real: 9 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 34
# gen loss: 0.08845673501491547 | disc_loss: 0.1294047087430954
# correctly identified real: 9 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 35
# gen loss: 0.0580318346619606 | disc_loss: 0.6818555593490601
# correctly identified real: 9 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 36
# gen loss: 0.05675382912158966 | disc_loss: 0.2624512314796448
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 37
# gen loss: 0.062476400285959244 | disc_loss: 0.18350669741630554
# correctly identified real: 11 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 38
# gen loss: 0.050626158714294434 | disc_loss: 0.2576831877231598
# correctly identified real: 10 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 39
# gen loss: 0.05811335891485214 | disc_loss: 0.37155336141586304
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 40
# gen loss: 0.11578711867332458 | disc_loss: 0.016863137483596802
# correctly identified real: 8 / 11
# correctly identified fake: 7 / 11
# total count 11
# epoch #: 41
# gen loss: 0.057283420115709305 | disc_loss: 0.29644975066185
# correctly identified real: 7 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 42
# gen loss: 0.057305797934532166 | disc_loss: 0.4453113079071045
# correctly identified real: 9 / 11
# correctly identified fake: 7 / 11
# total count 11
# epoch #: 43
# gen loss: 0.11510641872882843 | disc_loss: 0.02130298689007759
# correctly identified real: 8 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 44
# gen loss: 0.07065176963806152 | disc_loss: 0.4623136520385742
# correctly identified real: 9 / 11
# correctly identified fake: 8 / 11
# total count 11
# epoch #: 45
# gen loss: 0.05554034188389778 | disc_loss: 0.5523161888122559
# correctly identified real: 10 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 46
# gen loss: 0.052657827734947205 | disc_loss: 0.1550517976284027
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 47
# gen loss: 0.05006644129753113 | disc_loss: 0.17360864579677582
# correctly identified real: 11 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 48
# gen loss: 0.054778747260570526 | disc_loss: 0.25814419984817505
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 49
# gen loss: 0.09510564059019089 | disc_loss: 0.14120927453041077
# correctly identified real: 9 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 50
# gen loss: 0.051373615860939026 | disc_loss: 0.0896783322095871
# correctly identified real: 10 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 51
# gen loss: 0.053805556148290634 | disc_loss: 0.5348487496376038
# correctly identified real: 10 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 52
# gen loss: 0.062199100852012634 | disc_loss: 0.12595562636852264
# correctly identified real: 11 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 53
# gen loss: 0.09560172259807587 | disc_loss: 0.020353764295578003
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 54
# gen loss: 0.08339151740074158 | disc_loss: 0.2687489986419678
# correctly identified real: 11 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 55
# gen loss: 0.05404328927397728 | disc_loss: 0.15246598422527313
# correctly identified real: 9 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 56
# gen loss: 0.0517248772084713 | disc_loss: 0.2654278576374054
# correctly identified real: 10 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 57
# gen loss: 0.05248572677373886 | disc_loss: 0.3245165944099426
# correctly identified real: 9 / 11
# correctly identified fake: 8 / 11
# total count 11
# epoch #: 58
# gen loss: 0.112863689661026 | disc_loss: 0.016271915286779404
# correctly identified real: 10 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 59
# gen loss: 0.04245053231716156 | disc_loss: 0.6870811581611633
# correctly identified real: 8 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 60
# gen loss: 0.03820091858506203 | disc_loss: 0.40052103996276855
# correctly identified real: 10 / 11
# correctly identified fake: 7 / 11
# total count 11
# epoch #: 61
# gen loss: 0.04560902342200279 | disc_loss: 0.38146618008613586
# correctly identified real: 8 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 62
# gen loss: 0.04586940258741379 | disc_loss: 0.23555780947208405
# correctly identified real: 9 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 63
# gen loss: 0.046793218702077866 | disc_loss: 0.8643985986709595
# correctly identified real: 9 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 64
# gen loss: 0.044890500605106354 | disc_loss: 1.1751582622528076
# correctly identified real: 9 / 11
# correctly identified fake: 7 / 11
# total count 11
# epoch #: 65
# gen loss: 0.05119561776518822 | disc_loss: 0.17265287041664124
# correctly identified real: 6 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 66
# gen loss: 0.078433096408844 | disc_loss: 0.24500037729740143
# correctly identified real: 9 / 11
# correctly identified fake: 7 / 11
# total count 11
# epoch #: 67
# gen loss: 0.05066045746207237 | disc_loss: 0.7626866102218628
# correctly identified real: 9 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 68
# gen loss: 0.06118859723210335 | disc_loss: 0.520721435546875
# correctly identified real: 10 / 11
# correctly identified fake: 8 / 11
# total count 11
# epoch #: 69
# gen loss: 0.056582555174827576 | disc_loss: 0.19114844501018524
# correctly identified real: 6 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 70
# gen loss: 0.04860235005617142 | disc_loss: 0.3174864947795868
# correctly identified real: 10 / 11
# correctly identified fake: 7 / 11
# total count 11
# epoch #: 71
# gen loss: 0.05929742008447647 | disc_loss: 0.8160145878791809
# correctly identified real: 5 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 72
# gen loss: 0.04881460964679718 | disc_loss: 0.32850128412246704
# correctly identified real: 10 / 11
# correctly identified fake: 6 / 11
# total count 11
# epoch #: 73
# gen loss: 0.045527324080467224 | disc_loss: 0.273939847946167
# correctly identified real: 7 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 74
# gen loss: 0.04898979142308235 | disc_loss: 0.4010680019855499
# correctly identified real: 10 / 11
# correctly identified fake: 7 / 11
# total count 11
# epoch #: 75
# gen loss: 0.04102671518921852 | disc_loss: 0.2717970311641693
# correctly identified real: 10 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 76
# gen loss: 0.10792574286460876 | disc_loss: 0.013846145942807198
# correctly identified real: 11 / 11
# correctly identified fake: 8 / 11
# total count 11
# epoch #: 77
# gen loss: 0.05015966296195984 | disc_loss: 0.5576234459877014
# correctly identified real: 9 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 78
# gen loss: 0.049028314650058746 | disc_loss: 0.35465794801712036
# correctly identified real: 11 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 79
# gen loss: 0.0491240955889225 | disc_loss: 0.06006118282675743
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 80
# gen loss: 0.04600680246949196 | disc_loss: 0.3456684648990631
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 81
# gen loss: 0.055019937455654144 | disc_loss: 0.16209660470485687
# correctly identified real: 11 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 82
# gen loss: 0.07842810451984406 | disc_loss: 0.03665260598063469
# correctly identified real: 9 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 83
# gen loss: 0.1068267822265625 | disc_loss: 0.010291571728885174
# correctly identified real: 10 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 84
# gen loss: 0.05300363153219223 | disc_loss: 0.8959655165672302
# correctly identified real: 10 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 85
# gen loss: 0.05670025199651718 | disc_loss: 0.7101974487304688
# correctly identified real: 10 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 86
# gen loss: 0.08731479942798615 | disc_loss: 0.010668084025382996
# correctly identified real: 9 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 87
# gen loss: 0.08118841797113419 | disc_loss: 0.031710945069789886
# correctly identified real: 11 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 88
# gen loss: 0.04965081065893173 | disc_loss: 0.4289476275444031
# correctly identified real: 8 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 89
# gen loss: 0.059611305594444275 | disc_loss: 0.6913246512413025
# correctly identified real: 10 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 90
# gen loss: 0.0823315680027008 | disc_loss: 0.39091286063194275
# correctly identified real: 8 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 91
# gen loss: 0.04934589937329292 | disc_loss: 1.242763638496399
# correctly identified real: 10 / 11
# correctly identified fake: 6 / 11
# total count 11
# epoch #: 92
# gen loss: 0.03218577802181244 | disc_loss: 1.5876026153564453
# correctly identified real: 7 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 93
# gen loss: 0.07051980495452881 | disc_loss: 0.23890164494514465
# correctly identified real: 10 / 11
# correctly identified fake: 6 / 11
# total count 11
# epoch #: 94
# gen loss: 0.041125353425741196 | disc_loss: 0.4258016347885132
# correctly identified real: 8 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 95
# gen loss: 0.0413341149687767 | disc_loss: 0.44522958993911743
# correctly identified real: 9 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 96
# gen loss: 0.04950373247265816 | disc_loss: 0.36992350220680237
# correctly identified real: 11 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 97
# gen loss: 0.10659162700176239 | disc_loss: 0.023940496146678925
# correctly identified real: 8 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 98
# gen loss: 0.05285078287124634 | disc_loss: 0.4721342623233795
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 99
# gen loss: 0.043216533958911896 | disc_loss: 0.40980371832847595
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 100
# gen loss: 0.05220165103673935 | disc_loss: 0.10296550393104553
# correctly identified real: 11 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 101
# gen loss: 0.03880561143159866 | disc_loss: 0.3788295388221741
# correctly identified real: 8 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 102
# gen loss: 0.05150391161441803 | disc_loss: 0.0886899083852768
# correctly identified real: 10 / 11
# correctly identified fake: 8 / 11
# total count 11
# epoch #: 103
# gen loss: 0.037167176604270935 | disc_loss: 0.859018862247467
# correctly identified real: 8 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 104
# gen loss: 0.07723397761583328 | disc_loss: 0.26410791277885437
# correctly identified real: 11 / 11
# correctly identified fake: 7 / 11
# total count 11
# epoch #: 105
# gen loss: 0.10603221505880356 | disc_loss: 0.01660381443798542
# correctly identified real: 8 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 106
# gen loss: 0.048190876841545105 | disc_loss: 0.06457378715276718
# correctly identified real: 11 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 107
# gen loss: 0.05101693049073219 | disc_loss: 0.26915156841278076
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 108
# gen loss: 0.04934033751487732 | disc_loss: 0.06699371337890625
# correctly identified real: 10 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 109
# gen loss: 0.04546785354614258 | disc_loss: 0.19152146577835083
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 110
# gen loss: 0.10487958043813705 | disc_loss: 0.026225650683045387
# correctly identified real: 10 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 111
# gen loss: 0.07457644492387772 | disc_loss: 0.023448355495929718
# correctly identified real: 11 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 112
# gen loss: 0.038389213383197784 | disc_loss: 0.11143594235181808
# correctly identified real: 10 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 113
# gen loss: 0.04246523231267929 | disc_loss: 0.20753034949302673
# correctly identified real: 9 / 11
# correctly identified fake: 8 / 11
# total count 11
# epoch #: 114
# gen loss: 0.045132115483284 | disc_loss: 0.36348944902420044
# correctly identified real: 9 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 115
# gen loss: 0.04483983293175697 | disc_loss: 0.3397780656814575
# correctly identified real: 9 / 11
# correctly identified fake: 8 / 11
# total count 11
# epoch #: 116
# gen loss: 0.033087484538555145 | disc_loss: 0.49543753266334534
# correctly identified real: 8 / 11
# correctly identified fake: 8 / 11
# total count 11
# epoch #: 117
# gen loss: 0.1032550185918808 | disc_loss: 0.012001742608845234
# correctly identified real: 9 / 11
# correctly identified fake: 6 / 11
# total count 11
# epoch #: 118
# gen loss: 0.0486883707344532 | disc_loss: 0.5992098450660706
# correctly identified real: 7 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 119
# gen loss: 0.04339556768536568 | disc_loss: 0.5740906596183777
# correctly identified real: 11 / 11
# correctly identified fake: 4 / 11
# total count 11
# epoch #: 120
# gen loss: 0.03993218392133713 | disc_loss: 0.2507140338420868
# correctly identified real: 7 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 121
# gen loss: 0.04278937354683876 | disc_loss: 0.4189053773880005
# correctly identified real: 11 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 122
# gen loss: 0.035588666796684265 | disc_loss: 0.3870578408241272
# correctly identified real: 9 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 123
# gen loss: 0.041836217045784 | disc_loss: 0.5293921828269958
# correctly identified real: 11 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 124
# gen loss: 0.038552362471818924 | disc_loss: 1.1334832906723022
# correctly identified real: 9 / 11
# correctly identified fake: 7 / 11
# total count 11
# epoch #: 125
# gen loss: 0.04164173826575279 | disc_loss: 0.24211427569389343
# correctly identified real: 8 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 126
# gen loss: 0.045092884451150894 | disc_loss: 0.07561660557985306
# correctly identified real: 10 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 127
# gen loss: 0.03614853322505951 | disc_loss: 1.315903902053833
# correctly identified real: 9 / 11
# correctly identified fake: 8 / 11
# total count 11
# epoch #: 128
# gen loss: 0.053033143281936646 | disc_loss: 0.17966517806053162
# correctly identified real: 10 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 129
# gen loss: 0.04911709576845169 | disc_loss: 0.21860241889953613
# correctly identified real: 10 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 130
# gen loss: 0.04993909224867821 | disc_loss: 0.1620362102985382
# correctly identified real: 9 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 131
# gen loss: 0.03717920556664467 | disc_loss: 0.6847946047782898
# correctly identified real: 10 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 132
# gen loss: 0.04633006826043129 | disc_loss: 0.36550453305244446
# correctly identified real: 10 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 133
# gen loss: 0.03993269056081772 | disc_loss: 0.5599141120910645
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 134
# gen loss: 0.03989587724208832 | disc_loss: 0.22923065721988678
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 135
# gen loss: 0.04035929962992668 | disc_loss: 0.1905396580696106
# correctly identified real: 10 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 136
# gen loss: 0.0733465701341629 | disc_loss: 0.018172860145568848
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 137
# gen loss: 0.07049392908811569 | disc_loss: 0.032104235142469406
# correctly identified real: 11 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 138
# gen loss: 0.042279914021492004 | disc_loss: 0.11921115964651108
# correctly identified real: 9 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 139
# gen loss: 0.05161941051483154 | disc_loss: 0.15085947513580322
# correctly identified real: 11 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 140
# gen loss: 0.1036515161395073 | disc_loss: 0.0054231733083724976
# correctly identified real: 9 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 141
# gen loss: 0.05567953735589981 | disc_loss: 0.08547572046518326
# correctly identified real: 10 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 142
# gen loss: 0.04700199514627457 | disc_loss: 0.025802355259656906
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 143
# gen loss: 0.052519287914037704 | disc_loss: 0.1829482614994049
# correctly identified real: 11 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 144
# gen loss: 0.050758205354213715 | disc_loss: 0.17604288458824158
# correctly identified real: 10 / 11
# correctly identified fake: 11 / 11
# total count 11
# epoch #: 145
# gen loss: 0.03931419923901558 | disc_loss: 0.2294006645679474
# correctly identified real: 10 / 11
# correctly identified fake: 8 / 11
# total count 11
# epoch #: 146
# gen loss: 0.03867209702730179 | disc_loss: 0.7719920873641968
# correctly identified real: 9 / 11
# correctly identified fake: 10 / 11
# total count 11
# epoch #: 147
# gen loss: 0.061480890959501266 | disc_loss: 0.5096989870071411
# correctly identified real: 10 / 11
# correctly identified fake: 8 / 11
# total count 11
# epoch #: 148
# gen loss: 0.03631909191608429 | disc_loss: 0.4521767497062683
# correctly identified real: 9 / 11
# correctly identified fake: 9 / 11
# total count 11
# epoch #: 149
# gen loss: 0.04886753484606743 | disc_loss: 0.12999339401721954
# correctly identified real: 9 / 11
# correctly identified fake: 10 / 11
# total count 11

# %%
test_count = 0
import random
from skimage import color, io
predicted_rgb_batch = []
num = random.randint(0,1000)
for step, (img_lab, clas) in enumerate(train_loader):
    grey_img = img_lab[:,0:1,:,:]
    output = gen_model_2(grey_img)
    out_fake_disc = disc_model_2(output.detach())
    if(out_fake_disc < 0.5):
        predicted_rgb_img = color.lab2rgb(np.transpose(output[0].detach().numpy().astype('float64'), (1, 2, 0)))
        predicted_rgb_batch.append(torch.FloatTensor(output[0]))
        break

fig, ax = plt.subplots(figsize=(15, 15), nrows=1, ncols=2)
ax[0].imshow(np.transpose(torchvision.utils.make_grid(torch.stack(predicted_rgb_batch), nrow=5).detach().numpy(), (1, 2, 0)))
plt.show()
